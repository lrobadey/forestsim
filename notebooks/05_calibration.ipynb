# %% [markdown]
# # Calibration Workflow
#
# Load the checked-in Phase 4 artifacts generated from the synthetic demo package.

# %%
from pathlib import Path
import json
import pandas as pd

OUTPUT_DIR = Path('../data/sites/synthetic_demo/expected/phase4')
runs = pd.read_csv(OUTPUT_DIR / 'runs.csv')
accepted = pd.read_csv(OUTPUT_DIR / 'accepted_runs.csv')
print(runs[['sample_index', 'total_distance', 'accepted']].head())
print(json.loads((OUTPUT_DIR / 'best_run.json').read_text()))
