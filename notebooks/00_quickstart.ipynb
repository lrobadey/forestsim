# %% [markdown]
# # Quickstart
#
# Load the synthetic demo site, run the baseline workflow, and inspect the summary payload.

# %%
from pathlib import Path
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from wattforest import LandscapeInitializer
from wattforest.events import EventType, SimEvent
from wattforest.metrics import PatternMetrics

MANIFEST = Path('../data/sites/synthetic_demo/site_manifest.json')
result = LandscapeInitializer.run_phase3_baseline(MANIFEST, end_year=2025)
print(result.site_id, result.start_year, result.end_year)
print(result.simulated.to_dict())
